# %% [markdown]
# <a href="https://colab.research.google.com/github/kpreethi966-crypto/ML-LAB-EXPERIMENTS/blob/main/EX13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask requests pandas numpy scikit-learn

# %%
from google.colab import files

uploaded = files.upload()
text
iris_dataset.csv
# Out:
#      <input type="file" id="files-197d5e24-9303-4104-b14f-dea5160bce58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-197d5e24-9303-4104-b14f-dea5160bce58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("iris_dataset.csv")

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  target
# 0           5.1          3.5           1.4          0.2       0
# 1           4.9          3.0           1.4          0.2       0
# 2           4.7          3.2           1.3          0.2       0
# 3           4.6          3.1           1.5          0.2       0
# 4           5.0          3.6           1.4          0.2       0

# %%
X = df[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
y = df["target"]

print("Features Shape:", X.shape)
print("Target Shape:",y.shape)
# Out:
# Features Shape: (150, 4)
# Target Shape: (150,)

# %%
from sklearn.svm import SVC

model = SVC()

model.fit(X, y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
from flask import Flask, request, jsonify
import numpy as np

# Create Flask app again
app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()

    features = np.array(data['features']).reshape(1, -1)

    prediction = model.predict(features)

    return jsonify({
        'prediction': int(prediction[0])
    })


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with watchdog (inotify)

# %%
import threading

thread = threading.Thread(
    target=lambda: app.run(host="0.0.0.0", port=5000),
    daemon=True
)

thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# Exception in thread Thread-5 (<lambda>):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/threading.py", line 1044, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/threading.py", line 995, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1498/2298119041.py", line 4, in <lambda>
#     target=lambda: app.run(host="0.0.0.0", port=5000),
#                    ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/flask/app.py", line 662, in run
# ...

# %%
from flask import Flask, request, jsonify
import numpy as np
import threading

app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()

    features = np.array(data['features']).reshape(1, -1)

    prediction = model.predict(features)

    return jsonify({
        'prediction': int(prediction[0])
    })

def run_flask():
    app.run(host='127.0.0.1', port=5000, debug=False, use_reloader=False)

thread = threading.Thread(target=run_flask)
thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off

# %%
import requests

url = "http://127.0.0.1:5000/predict"

data = {
    "features": [5.1, 3.5, 1.4, 0.2]
}

response = requests.post(url, json=data)

print(response.json())
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# INFO:werkzeug:127.0.0.1 - - [05/Sep/2026 13:36:15] "POST /predict HTTP/1.1" 200 -
# {'prediction': 0}

# %%
data = {
    "features": [6.7, 3.1, 4.7, 1.5]
}

response = requests.post(url, json=data)

print(response.json())
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# INFO:werkzeug:127.0.0.1 - - [05/Sep/2026 13:37:53] "POST /predict HTTP/1.1" 200 -
# {'prediction': 1}
